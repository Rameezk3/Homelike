# %%
import pandas as pd

# %%
data=pd.read_csv('task_data.csv')
data['datetime'] =pd.to_datetime(data.datetime)
data
# Out:
#                               datetime  \
# 0     2021-01-23 11:57:09.286000+00:00
# 1     2021-01-23 11:57:02.303000+00:00
# 2     2021-01-23 11:57:01.873999+00:00
# 3     2021-01-23 11:57:02.028000+00:00
# 4     2021-01-23 11:57:04.349000+00:00
# ...                                ...
# 76533 2021-01-23 12:58:08.093999+00:00
# 76534 2021-01-23 14:48:29.653000+00:00
# 76535 2021-01-23 13:07:43.169999+00:00
# 76536 2021-01-23 13:07:42.997000+00:00
# 76537 2021-01-23 13:14:31.409999+00:00
#
#                                      session_id  \
# 0      56b8ee8e3467edb774252ddeec6d9243e13b5fc9
# 1      fb651c2fcb0f529123439d8c2a77ec722f14bf98
# 2      fb651c2fcb0f529123439d8c2a77ec722f14bf98
# 3      fb651c2fcb0f529123439d8c2a77ec722f14bf98
# 4      fb651c2fcb0f529123439d8c2a77ec722f14bf98
# ...                                         ...
# 76533  8bc40fec35a79acf0248fa42afcff0a2c232d53d
# 76534  02cd3cb1ea4f9bffedfcfc694459072c18364bc4
# 76535  9d82efe6b326b54660893bafd61ce0c26de2d341
# 76536  9d82efe6b326b54660893bafd61ce0c26de2d341
# 76537                                       NaN
#
#                                      visitor_id  is_internal_ip  \
# 0      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# 1      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# 2      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# 3      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# 4      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# ...                                         ...             ...
# 76533  a0e77abef642ebc507e1d7636680f59300396514           False
# 76534  ed2f8bb5a943dccd935170b7f06895732b710392           False
# 76535  460bf530d5efbd784335e4dc2f15692e97573e3a           False
# 76536  460bf530d5efbd784335e4dc2f15692e97573e3a           False
# 76537                                       NaN           False
#
#             page_type                     event_type  \
# 0      apartment_view       apartment_gallery_opened
# 1      apartment_view            apartment_date_init
# 2      apartment_view                 page_view_init
# 3      apartment_view                      page_view
# 4      apartment_view      cookie_banner_all_cookies
# ...               ...                            ...
# 76533  apartment_view  apartment_image_gallery_swipe
# 76534  apartment_view            apartment_date_init
# 76535  apartment_view                      page_view
# 76536  apartment_view                 page_view_init
# 76537  apartment_view                 page_view_init
#
#                                                   params om_source  \
# 0      {"event_content":{},"page":{"title":"EXKLUSIVE...       NaN
# 1      {"event_content":{"start":"2021-08-01","end":"...  nestpick
# 2      {"page":{"page_type":"apartment_view","country...  nestpick
# 3      {"event_content":{},"page":{"title":"EXKLUSIVE...  nestpick
# 4      {"page":{"title":"EXKLUSIVE WOHNUNG SALAMANCA ...  nestpick
# ...                                                  ...       ...
# 76533  {"event_content":{"ga":{"category":"Tile Pictu...  facebook
# 76534  {"event_content":{"start":"2021-02-01","end":"...  facebook
# 76535  {"event_content":{},"page":{"title":"Nice apar...  facebook
# 76536  {"page":{"page_type":"apartment_view","country...  facebook
# 76537  {"page":{"page_type":"apartment_view","country...       NaN
#
#       device_class         env
# 0            phone  production
# 1            phone  production
# 2            phone  production
# 3            phone  production
# 4            phone  production
# ...            ...         ...
# 76533        phone  production
# 76534        phone  production
# 76535        phone  production
# 76536        phone  production
# 76537        other  production
#
# [76538 rows x 10 columns]

# %%
#filter to get only enviornment 
data= data[data['env'].isin(['production'])]
data
# Out:
#                               datetime  \
# 0     2021-01-23 11:57:09.286000+00:00
# 1     2021-01-23 11:57:02.303000+00:00
# 2     2021-01-23 11:57:01.873999+00:00
# 3     2021-01-23 11:57:02.028000+00:00
# 4     2021-01-23 11:57:04.349000+00:00
# ...                                ...
# 76533 2021-01-23 12:58:08.093999+00:00
# 76534 2021-01-23 14:48:29.653000+00:00
# 76535 2021-01-23 13:07:43.169999+00:00
# 76536 2021-01-23 13:07:42.997000+00:00
# 76537 2021-01-23 13:14:31.409999+00:00
#
#                                      session_id  \
# 0      56b8ee8e3467edb774252ddeec6d9243e13b5fc9
# 1      fb651c2fcb0f529123439d8c2a77ec722f14bf98
# 2      fb651c2fcb0f529123439d8c2a77ec722f14bf98
# 3      fb651c2fcb0f529123439d8c2a77ec722f14bf98
# 4      fb651c2fcb0f529123439d8c2a77ec722f14bf98
# ...                                         ...
# 76533  8bc40fec35a79acf0248fa42afcff0a2c232d53d
# 76534  02cd3cb1ea4f9bffedfcfc694459072c18364bc4
# 76535  9d82efe6b326b54660893bafd61ce0c26de2d341
# 76536  9d82efe6b326b54660893bafd61ce0c26de2d341
# 76537                                       NaN
#
#                                      visitor_id  is_internal_ip  \
# 0      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# 1      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# 2      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# 3      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# 4      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# ...                                         ...             ...
# 76533  a0e77abef642ebc507e1d7636680f59300396514           False
# 76534  ed2f8bb5a943dccd935170b7f06895732b710392           False
# 76535  460bf530d5efbd784335e4dc2f15692e97573e3a           False
# 76536  460bf530d5efbd784335e4dc2f15692e97573e3a           False
# 76537                                       NaN           False
#
#             page_type                     event_type  \
# 0      apartment_view       apartment_gallery_opened
# 1      apartment_view            apartment_date_init
# 2      apartment_view                 page_view_init
# 3      apartment_view                      page_view
# 4      apartment_view      cookie_banner_all_cookies
# ...               ...                            ...
# 76533  apartment_view  apartment_image_gallery_swipe
# 76534  apartment_view            apartment_date_init
# 76535  apartment_view                      page_view
# 76536  apartment_view                 page_view_init
# 76537  apartment_view                 page_view_init
#
#                                                   params om_source  \
# 0      {"event_content":{},"page":{"title":"EXKLUSIVE...       NaN
# 1      {"event_content":{"start":"2021-08-01","end":"...  nestpick
# 2      {"page":{"page_type":"apartment_view","country...  nestpick
# 3      {"event_content":{},"page":{"title":"EXKLUSIVE...  nestpick
# 4      {"page":{"title":"EXKLUSIVE WOHNUNG SALAMANCA ...  nestpick
# ...                                                  ...       ...
# 76533  {"event_content":{"ga":{"category":"Tile Pictu...  facebook
# 76534  {"event_content":{"start":"2021-02-01","end":"...  facebook
# 76535  {"event_content":{},"page":{"title":"Nice apar...  facebook
# 76536  {"page":{"page_type":"apartment_view","country...  facebook
# 76537  {"page":{"page_type":"apartment_view","country...       NaN
#
#       device_class         env
# 0            phone  production
# 1            phone  production
# 2            phone  production
# 3            phone  production
# 4            phone  production
# ...            ...         ...
# 76533        phone  production
# 76534        phone  production
# 76535        phone  production
# 76536        phone  production
# 76537        other  production
#
# [76483 rows x 10 columns]

# %%
# filter not internal traffic (is_internal_ip= False)

data=data[data['is_internal_ip']==False]
data
# Out:
#                               datetime  \
# 0     2021-01-23 11:57:09.286000+00:00
# 1     2021-01-23 11:57:02.303000+00:00
# 2     2021-01-23 11:57:01.873999+00:00
# 3     2021-01-23 11:57:02.028000+00:00
# 4     2021-01-23 11:57:04.349000+00:00
# ...                                ...
# 76533 2021-01-23 12:58:08.093999+00:00
# 76534 2021-01-23 14:48:29.653000+00:00
# 76535 2021-01-23 13:07:43.169999+00:00
# 76536 2021-01-23 13:07:42.997000+00:00
# 76537 2021-01-23 13:14:31.409999+00:00
#
#                                      session_id  \
# 0      56b8ee8e3467edb774252ddeec6d9243e13b5fc9
# 1      fb651c2fcb0f529123439d8c2a77ec722f14bf98
# 2      fb651c2fcb0f529123439d8c2a77ec722f14bf98
# 3      fb651c2fcb0f529123439d8c2a77ec722f14bf98
# 4      fb651c2fcb0f529123439d8c2a77ec722f14bf98
# ...                                         ...
# 76533  8bc40fec35a79acf0248fa42afcff0a2c232d53d
# 76534  02cd3cb1ea4f9bffedfcfc694459072c18364bc4
# 76535  9d82efe6b326b54660893bafd61ce0c26de2d341
# 76536  9d82efe6b326b54660893bafd61ce0c26de2d341
# 76537                                       NaN
#
#                                      visitor_id  is_internal_ip  \
# 0      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# 1      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# 2      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# 3      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# 4      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# ...                                         ...             ...
# 76533  a0e77abef642ebc507e1d7636680f59300396514           False
# 76534  ed2f8bb5a943dccd935170b7f06895732b710392           False
# 76535  460bf530d5efbd784335e4dc2f15692e97573e3a           False
# 76536  460bf530d5efbd784335e4dc2f15692e97573e3a           False
# 76537                                       NaN           False
#
#             page_type                     event_type  \
# 0      apartment_view       apartment_gallery_opened
# 1      apartment_view            apartment_date_init
# 2      apartment_view                 page_view_init
# 3      apartment_view                      page_view
# 4      apartment_view      cookie_banner_all_cookies
# ...               ...                            ...
# 76533  apartment_view  apartment_image_gallery_swipe
# 76534  apartment_view            apartment_date_init
# 76535  apartment_view                      page_view
# 76536  apartment_view                 page_view_init
# 76537  apartment_view                 page_view_init
#
#                                                   params om_source  \
# 0      {"event_content":{},"page":{"title":"EXKLUSIVE...       NaN
# 1      {"event_content":{"start":"2021-08-01","end":"...  nestpick
# 2      {"page":{"page_type":"apartment_view","country...  nestpick
# 3      {"event_content":{},"page":{"title":"EXKLUSIVE...  nestpick
# 4      {"page":{"title":"EXKLUSIVE WOHNUNG SALAMANCA ...  nestpick
# ...                                                  ...       ...
# 76533  {"event_content":{"ga":{"category":"Tile Pictu...  facebook
# 76534  {"event_content":{"start":"2021-02-01","end":"...  facebook
# 76535  {"event_content":{},"page":{"title":"Nice apar...  facebook
# 76536  {"page":{"page_type":"apartment_view","country...  facebook
# 76537  {"page":{"page_type":"apartment_view","country...       NaN
#
#       device_class         env
# 0            phone  production
# 1            phone  production
# 2            phone  production
# 3            phone  production
# 4            phone  production
# ...            ...         ...
# 76533        phone  production
# 76534        phone  production
# 76535        phone  production
# 76536        phone  production
# 76537        other  production
#
# [76483 rows x 10 columns]

# %%
# third filter rows without a session_id, page_type, event_type
data= data[data['session_id'].notnull() & data['page_type'].notnull() & data['event_type'].notnull()] 
data
# Out:
#                               datetime  \
# 0     2021-01-23 11:57:09.286000+00:00
# 1     2021-01-23 11:57:02.303000+00:00
# 2     2021-01-23 11:57:01.873999+00:00
# 3     2021-01-23 11:57:02.028000+00:00
# 4     2021-01-23 11:57:04.349000+00:00
# ...                                ...
# 76532 2021-01-23 13:06:10.991000+00:00
# 76533 2021-01-23 12:58:08.093999+00:00
# 76534 2021-01-23 14:48:29.653000+00:00
# 76535 2021-01-23 13:07:43.169999+00:00
# 76536 2021-01-23 13:07:42.997000+00:00
#
#                                      session_id  \
# 0      56b8ee8e3467edb774252ddeec6d9243e13b5fc9
# 1      fb651c2fcb0f529123439d8c2a77ec722f14bf98
# 2      fb651c2fcb0f529123439d8c2a77ec722f14bf98
# 3      fb651c2fcb0f529123439d8c2a77ec722f14bf98
# 4      fb651c2fcb0f529123439d8c2a77ec722f14bf98
# ...                                         ...
# 76532  8bc40fec35a79acf0248fa42afcff0a2c232d53d
# 76533  8bc40fec35a79acf0248fa42afcff0a2c232d53d
# 76534  02cd3cb1ea4f9bffedfcfc694459072c18364bc4
# 76535  9d82efe6b326b54660893bafd61ce0c26de2d341
# 76536  9d82efe6b326b54660893bafd61ce0c26de2d341
#
#                                      visitor_id  is_internal_ip  \
# 0      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# 1      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# 2      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# 3      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# 4      fb651c2fcb0f529123439d8c2a77ec722f14bf98           False
# ...                                         ...             ...
# 76532  a0e77abef642ebc507e1d7636680f59300396514           False
# 76533  a0e77abef642ebc507e1d7636680f59300396514           False
# 76534  ed2f8bb5a943dccd935170b7f06895732b710392           False
# 76535  460bf530d5efbd784335e4dc2f15692e97573e3a           False
# 76536  460bf530d5efbd784335e4dc2f15692e97573e3a           False
#
#             page_type                     event_type  \
# 0      apartment_view       apartment_gallery_opened
# 1      apartment_view            apartment_date_init
# 2      apartment_view                 page_view_init
# 3      apartment_view                      page_view
# 4      apartment_view      cookie_banner_all_cookies
# ...               ...                            ...
# 76532  apartment_view  apartment_image_gallery_swipe
# 76533  apartment_view  apartment_image_gallery_swipe
# 76534  apartment_view            apartment_date_init
# 76535  apartment_view                      page_view
# 76536  apartment_view                 page_view_init
#
#                                                   params om_source  \
# 0      {"event_content":{},"page":{"title":"EXKLUSIVE...       NaN
# 1      {"event_content":{"start":"2021-08-01","end":"...  nestpick
# 2      {"page":{"page_type":"apartment_view","country...  nestpick
# 3      {"event_content":{},"page":{"title":"EXKLUSIVE...  nestpick
# 4      {"page":{"title":"EXKLUSIVE WOHNUNG SALAMANCA ...  nestpick
# ...                                                  ...       ...
# 76532  {"event_content":{"ga":{"category":"Tile Pictu...  facebook
# 76533  {"event_content":{"ga":{"category":"Tile Pictu...  facebook
# 76534  {"event_content":{"start":"2021-02-01","end":"...  facebook
# 76535  {"event_content":{},"page":{"title":"Nice apar...  facebook
# 76536  {"page":{"page_type":"apartment_view","country...  facebook
#
#       device_class         env
# 0            phone  production
# 1            phone  production
# 2            phone  production
# 3            phone  production
# 4            phone  production
# ...            ...         ...
# 76532        phone  production
# 76533        phone  production
# 76534        phone  production
# 76535        phone  production
# 76536        phone  production
#
# [75861 rows x 10 columns]

# %%
# Show user count by type device_class
user_device_class = pd.DataFrame(data.groupby('device_class'))
user_device_class[0]
# Out:
# 0        bot
# 1    desktop
# 2      other
# 3      phone
# 4     tablet
# Name: 0, dtype: object

# %%
#  Show user count by each user's first (min datetime) non-null om_source . If the user
#  journey contains no data for om_source relabel the null value as “ no_om_source ”

user_with_dateTime = pd.DataFrame(data.groupby('device_class')['datetime'].min())


with_no_om_source=data[data['datetime'].isin(user_with_dateTime['datetime'])]
with_no_om_source['om_source']= with_no_om_source.om_source.fillna('no_om_source')
with_no_om_source
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                               datetime  \
# 3058  2021-01-23 11:19:09.873000+00:00
# 3068  2021-01-23 12:03:21.649000+00:00
# 39959 2021-01-23 11:00:01.442999+00:00
# 41847 2021-01-23 11:00:01.350000+00:00
# 71446 2021-01-23 11:00:00.737000+00:00
#
#                                      session_id  \
# 3058   92f39c0081e995777f2e3ce857f1367703a1e63f
# 3068   ded6d0a982266a91d4b17fc490425be950a7193b
# 39959  d500518cc68fbd0960fc802aca9dd2a92593c9ea
# 41847  2475f7655ea3adadc5cf0e4b799ac43e11d8c8c7
# 71446  a3fef7660ebc7dbd05a55bbe033325eb2125fd17
#
#                                      visitor_id  is_internal_ip  \
# 3058   92f39c0081e995777f2e3ce857f1367703a1e63f           False
# 3068   ded6d0a982266a91d4b17fc490425be950a7193b           False
# 39959  6319db4a62abaca90ad7692d26bf7257dac66c08           False
# 41847  2475f7655ea3adadc5cf0e4b799ac43e11d8c8c7           False
# 71446  f37a3a2285c601739a95c5e569514c4508423b00           False
#
#             page_type                       event_type  \
# 3058   apartment_view                   page_view_init
# 3068              cms                        page_view
# 39959     search_page  search_apartment-preview-closed
# 41847  apartment_view                   page_view_init
# 71446     search_page            Click on filter label
#
#                                                   params     om_source  \
# 3058   {"page":{"page_type":"apartment_view","country...  no_om_source
# 3068     {"event_content":{},"page":{"page_type":"cms"}}  no_om_source
# 39959  {"event_content":{"apartment_link":"/apartment...       adwords
# 41847  {"page":{"page_type":"apartment_view","country...       adwords
# 71446  {"event_content":{"ga":{"category":"Filter","a...  no_om_source
#
#       device_class         env
# 3058           bot  production
# 3068         other  production
# 39959       tablet  production
# 41847      desktop  production
# 71446        phone  production

# %%
# Show how many user journeys started on page_type=search_page and any point
#after in their user journey visited page_type=apartment_view

grouped_by_session=pd.DataFrame(data.groupby('session_id'))
grouped_by_session
# Out:
#                                              0  \
# 0     000727d438a0e2c05f6572373e74ee71c79d248b
# 1     001277072b953984f5d7fcf7575e06841fd30bc2
# 2     00442841b7b396c3358671e146a764602443d60f
# 3     00464d1e43c3de4bff653fcb75befb6f0a47ad9b
# 4     00484e342b45b0c1195ce9d48efc0bc3863e62b0
# ...                                        ...
# 3628  ffa92432b98ac27d446bef79f9f461a4209320f8
# 3629  ffaa802395d83ef7c3b4dc5b65fa7e7cf67344f5
# 3630  ffd3b0c4189d2bb7c1aecd73d0d924f230a3de83
# 3631  ffe7deadae038a7b488a00ee5ff33fd64276a60a
# 3632  fff8f0ca77cb0889d2701ff1e1c100f2572840c7
#
#                                                       1
# 0                                  datetime  \
# 3405 ...
# 1                                   datetime  \
# 4668...
# 2                                   datetime  \
# 3643...
# 3                                   datetime  \
# 7460...
# 4                                 datetime  \
# 680 20...
# ...                                                 ...
# 3628                               datetime  \
# 5618 ...
# 3629                                datetime  \
# 3807...
# 3630                               datetime  \
# 2761 ...
# 3631                                datetime  \
# 2456...
# 3632                                datetime  \
# 4651...
#
# [3633 rows x 2 columns]

# %%
# Show how many users had a session duration of <= 5 seconds

session_dict=dict()
session_searchpage=dict()
session_apparnment_view=dict()
for entity in (grouped_by_session[1].tolist()):
    sessions=entity.sort_values(by='datetime',ascending=False)
    if len(sessions) > 0:
        session_dateTime = sessions.datetime.tolist()
        #for task a
        if (sessions.page_type.tolist()[0] == "search_page"):
            session_searchpage[sessions.session_id.any()]=True
        # for task b
        if (sessions.page_type.tolist()[-1] == "apartment_view"):
            session_apparnment_view[sessions.session_id.any()]=True
            
        count=0
        for y in range(len(session_dateTime)-1):
            diff = session_dateTime[y] - session_dateTime[y+1]
            
            if (diff.total_seconds() <= 5):
                count+=1
        session_dict[sessions.session_id.any()]=count
    else:
        pass

# %%
session_with_count= pd.DataFrame.from_dict(list(session_dict.items())  )
session_with_count = session_with_count[session_with_count[1] >0]
session_with_count
# Out:
#                                              0   1
# 2     00442841b7b396c3358671e146a764602443d60f   3
# 3     00464d1e43c3de4bff653fcb75befb6f0a47ad9b   2
# 5     0048635b64173131a8eface0669e19406a8e4fdb   1
# 6     004da9a8ea34b132bb8cb2f78899c74ced50a940   2
# 7     005bd232b11eb192a669a68f27bb1408e87dff7e   1
# ...                                        ...  ..
# 3628  ffa92432b98ac27d446bef79f9f461a4209320f8   3
# 3629  ffaa802395d83ef7c3b4dc5b65fa7e7cf67344f5   2
# 3630  ffd3b0c4189d2bb7c1aecd73d0d924f230a3de83  39
# 3631  ffe7deadae038a7b488a00ee5ff33fd64276a60a   9
# 3632  fff8f0ca77cb0889d2701ff1e1c100f2572840c7  91
#
# [3144 rows x 2 columns]

# %%
#How many of those user journeys started on page_type=search_page
pd.DataFrame.from_dict(list(session_apparnment_view.items())  )
# Out:
#                                              0     1
# 0     001277072b953984f5d7fcf7575e06841fd30bc2  True
# 1     00442841b7b396c3358671e146a764602443d60f  True
# 2     0048635b64173131a8eface0669e19406a8e4fdb  True
# 3     004da9a8ea34b132bb8cb2f78899c74ced50a940  True
# 4     005bd232b11eb192a669a68f27bb1408e87dff7e  True
# ...                                        ...   ...
# 1578  ff6e89de64b04de74bc89ff1cbe027cfc85113b6  True
# 1579  ff75f462b1d9162807382e04e0bfd88a36f21605  True
# 1580  ff7fdc82d386167be8b3ae5dc3cf4baf9605f05f  True
# 1581  ffaa802395d83ef7c3b4dc5b65fa7e7cf67344f5  True
# 1582  fff8f0ca77cb0889d2701ff1e1c100f2572840c7  True
#
# [1583 rows x 2 columns]

# %%
#How many of those user journeys ended on page_type=apartment_view
pd.DataFrame.from_dict(list(session_searchpage.items())  )
# Out:
#                                              0     1
# 0     00464d1e43c3de4bff653fcb75befb6f0a47ad9b  True
# 1     0078698144856265558471927077e661e2834572  True
# 2     00b97acbd4f9ca54c46a5315f784274c20cc4af2  True
# 3     0119d163607911b5a889280e600775e1bb1f9c6c  True
# 4     0145bf6d174173fa66688fa767b57bb66c87783d  True
# ...                                        ...   ...
# 1710  ff9c085ffd1ca785e255bc3bd94653d17f77af75  True
# 1711  ffa92432b98ac27d446bef79f9f461a4209320f8  True
# 1712  ffd3b0c4189d2bb7c1aecd73d0d924f230a3de83  True
# 1713  ffe7deadae038a7b488a00ee5ff33fd64276a60a  True
# 1714  fff8f0ca77cb0889d2701ff1e1c100f2572840c7  True
#
# [1715 rows x 2 columns]

# %%
#Show how many user journeys started on page_type=search_page and any point
#after in their user journey visited page_type=apartment_view

user_searchpage=dict()
for entity in (grouped_by_session[1].tolist()):
    sessions=entity.sort_values(by='datetime',ascending=False)
    if (sessions.page_type.tolist()[0] == "search_page" and "apartment_view" in sessions.page_type.tolist()[1:] ):
        user_searchpage[sessions.session_id.any()]=True
    else:
        pass

# %%
# user journeys started on page_type=search_page and any point after in their user 
#journey visited page_type=apartment_view
pd.DataFrame.from_dict(list(user_searchpage.items())  )
# Out:
#                                             0     1
# 0    01ca56b32b60f2b0eacf791f76ace1febeb1da5f  True
# 1    03a390caa232c2bbaea2e86247a5d242b53f282a  True
# 2    044463626dee5259a26a894cd6d3546d97bf6d4b  True
# 3    044d4bc6e7bab364c5b9001e5b96320bd812ca6d  True
# 4    07be75ec9a40c59b424a44bc39b910b833da70e8  True
# ..                                        ...   ...
# 213  fdb5c350fd323bc298b86bef9a0811be322c914d  True
# 214  feaa1981bfbed33c5cbe4b729e0985e3e4858bd5  True
# 215  ff6e89de64b04de74bc89ff1cbe027cfc85113b6  True
# 216  ff75f462b1d9162807382e04e0bfd88a36f21605  True
# 217  fff8f0ca77cb0889d2701ff1e1c100f2572840c7  True
#
# [218 rows x 2 columns]

# %%
 #Show how many users at any point in their user journey executed an event_type =
# ‘click_book-now’

event_clicknow=dict()
for entity in (grouped_by_session[1].tolist()):
    sessions=entity.sort_values(by='datetime',ascending=False)
    if ("click_book-now" in sessions.event_type.tolist()):
        event_clicknow[sessions.session_id.any()]=True
    else:
        pass
    
pd.DataFrame.from_dict(list(event_clicknow.items())  )
# Out:
#                                            0     1
# 0   02ab1821160b5cdaf85864425b332693fd5b30d3  True
# 1   1181860330e7dde2f5311055c2c35cf08461ce20  True
# 2   1a94327b6b004d3bfad282abb47900103c609e81  True
# 3   1cb8087b1ab1e1cbc2b3c4be5a340832cd24544d  True
# 4   21b1eeef4b7185dca14cfbb4a1c7dd9346c4dcc1  True
# ..                                       ...   ...
# 62  e75423678721928018eb24abebb2b3cda621aa17  True
# 63  ed12c708c65e49b3b268a3b84369471b6f1bee2e  True
# 64  f313207230e732d99b6fd8ee364a2f3425a374df  True
# 65  f7e01bdc1a05d502a3a6c120ed45f376e68eb854  True
# 66  feaa1981bfbed33c5cbe4b729e0985e3e4858bd5  True
#
# [67 rows x 2 columns]

# %%
#Show how many users who started on page_type = search_page executed an
#event_type = ‘request_draft-created’
user_with_searchpyge_event_type=dict()
for entity in (grouped_by_session[1].tolist()):
    sessions=entity.sort_values(by='datetime',ascending=False)
    if (sessions.page_type.tolist()[0]=='search_page' and 'request_draft-created' in sessions.event_type.tolist()):
        user_with_searchpyge_event_type[sessions.session_id.any()]=True
    else:
        pass
    
pd.DataFrame.from_dict(list(user_with_searchpyge_event_type.items())  )
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## This following analysis measures your ability to extract data from a field with a JSON structure.
# ## You will make use of the params field data for the following analysis along with the other fields.

# %%
import json
from types import SimpleNamespace
#Show how many users set a price filter above 1200 EUR and how many set a price filter
#below 1200 EUR (e.g {"event_content":{"price":1200, “currency":"EUR”}}). If the
#currency is not EUR you can ignore that session.
val =str(pd.DataFrame(grouped_by_session[1].tolist()[0]).params)

x = json.loads(val, object_hook=lambda d: SimpleNamespace(**d))
print(x.event_content, x.page.page_type)
#pd.DataFrame(grouped_by_session[1].tolist()[0]).params
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-39-3572acfe6ca2> in <module>
#       6 val =str(pd.DataFrame(grouped_by_session[1].tolist()[0]).params)
#       7
# ----> 8 x = json.loads(val, object_hook=lambda d: SimpleNamespace(**d))
#       9 print(x.event_content, x.page.page_type)
#      10 #pd.DataFrame(grouped_by_session[1].tolist()[0]).params
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     359     if parse_constant is not None:
#     360         kw['parse_constant'] = parse_constant
# --> 361     return cls(**kw).decode(s)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     338         end = _w(s, end).end()
#     339         if end != len(s):
# --> 340             raise JSONDecodeError("Extra data", s, end)
#     341         return obj
#     342
#
# JSONDecodeError: Extra data: line 1 column 9 (char 8)
